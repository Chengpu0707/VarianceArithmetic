# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Cheng\OneDrive\Documents\Proj\VarianceArithemtic\IPyNb

# %%
df = pd.read_csv("../Python/Output/ExpLogError.txt", sep='\t')
df.head()
# Out:
#       X  VarDbl Error  VarDbl Uncertainty     Lib Error  Lib Uncertainty
# 0  0.00 -8.217184e-33        1.281966e-16  0.000000e+00     0.000000e+00
# 1 -0.02 -4.857226e-17        6.548514e-17 -4.857226e-17     2.832792e-18
# 2  0.02 -3.469447e-17        1.257060e-16 -3.469447e-17     2.832792e-18
# 3 -0.04 -3.469447e-17        6.707408e-17 -3.469447e-17     5.665583e-18
# 4  0.04 -1.387779e-17        1.233652e-16 -1.387779e-17     5.665583e-18

# %%
df['Normalized Error'] = df['VarDbl Error'] / df['VarDbl Uncertainty']
df.head()
# Out:
#       X  VarDbl Error  VarDbl Uncertainty     Lib Error  Lib Uncertainty  \
# 0  0.00 -8.217184e-33        1.281966e-16  0.000000e+00     0.000000e+00
# 1 -0.02 -4.857226e-17        6.548514e-17 -4.857226e-17     2.832792e-18
# 2  0.02 -3.469447e-17        1.257060e-16 -3.469447e-17     2.832792e-18
# 3 -0.04 -3.469447e-17        6.707408e-17 -3.469447e-17     5.665583e-18
# 4  0.04 -1.387779e-17        1.233652e-16 -1.387779e-17     5.665583e-18
#
#    Normalized Error
# 0     -6.409830e-17
# 1     -7.417295e-01
# 2     -2.759969e-01
# 3     -5.172560e-01
# 4     -1.124935e-01

# %%
print(df['Normalized Error'].std(), df['Normalized Error'].mean())
# Out:
# 0.2906859949382427 -0.01374502423095834

# %%
df[(df['X'] >= -1) & (df['X'] <= 1)]['Normalized Error'].std()
# Out:
# 0.408585282921376

# %%
df[(df['X'] >= -1) & (df['X'] <= 1)]['Normalized Error'].mean()
# Out:
# -0.02708178041545257

# %%
df = df.sort_values('X').set_index('X')
df.head()
# Out:
#        VarDbl Error  VarDbl Uncertainty  Lib Error  Lib Uncertainty  \
# X
# -1.98           0.0        2.505468e-16        0.0     1.812987e-16
# -1.96           0.0        2.494905e-16        0.0     1.812987e-16
# -1.94           0.0        2.484714e-16        0.0     1.812987e-16
# -1.92           0.0        2.474883e-16        0.0     1.812987e-16
# -1.90           0.0        2.465401e-16        0.0     1.812987e-16
#
#        Normalized Error
# X
# -1.98               0.0
# -1.96               0.0
# -1.94               0.0
# -1.92               0.0
# -1.90               0.0

# %%
df[['Lib Error', 'VarDbl Error', 'VarDbl Uncertainty']].plot(title=r'Numerical errors for log(e^x) - x', style=['-', '--', '-'])
# Out:
# <AxesSubplot:title={'center':'Numerical errors for log(e^x) - x'}, xlabel='X'>

# %%
df.hist(column='Normalized Error')
# Out:
# array([[<AxesSubplot:title={'center':'Normalized Error'}>]], dtype=object)
