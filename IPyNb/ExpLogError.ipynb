# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Cheng\OneDrive\Documents\Proj\VarianceArithemtic\IPyNb

# %%
df = pd.read_csv("../Python/Output/ExpLogError.txt", sep='\t')
df.head()
# Out:
#       X  VarDbl Error  VarDbl Uncertainty     Lib Error  Lib Uncertainty
# 0 -0.00  0.000000e+00        0.000000e+00  0.000000e+00     0.000000e+00
# 1  0.00  0.000000e+00        0.000000e+00  0.000000e+00     0.000000e+00
# 2 -0.02 -3.469447e-17        1.257059e-16 -4.857226e-17     2.832792e-18
# 3  0.02 -3.469447e-17        1.257059e-16 -3.469447e-17     2.832792e-18
# 4 -0.04 -1.387779e-17        1.233652e-16 -3.469447e-17     5.665583e-18

# %%
df['Normalized Error'] = df['VarDbl Error'] / df['VarDbl Uncertainty']
df.head()
# Out:
#       X  VarDbl Error  VarDbl Uncertainty     Lib Error  Lib Uncertainty  \
# 0 -0.00  0.000000e+00        0.000000e+00  0.000000e+00     0.000000e+00
# 1  0.00  0.000000e+00        0.000000e+00  0.000000e+00     0.000000e+00
# 2 -0.02 -3.469447e-17        1.257059e-16 -4.857226e-17     2.832792e-18
# 3  0.02 -3.469447e-17        1.257059e-16 -3.469447e-17     2.832792e-18
# 4 -0.04 -1.387779e-17        1.233652e-16 -3.469447e-17     5.665583e-18
#
#    Normalized Error
# 0               NaN
# 1               NaN
# 2         -0.275997
# 3         -0.275997
# 4         -0.112494

# %%
print(df['Normalized Error'].std(), df['Normalized Error'].mean())
# Out:
# 0.29431824518899286 -0.0011376485302478888

# %%
df[(df['X'] >= -1) & (df['X'] <= 1)]['Normalized Error'].std()
# Out:
# 0.41517338554873523

# %%
df[(df['X'] >= -1) & (df['X'] <= 1)]['Normalized Error'].mean()
# Out:
# -0.00225254408989082

# %%
df = df.sort_values('X').set_index('X')
df.head()
# Out:
#        VarDbl Error  VarDbl Uncertainty  Lib Error  Lib Uncertainty  \
# X
# -1.98           0.0        2.330578e-16        0.0     1.812987e-16
# -1.96           0.0        2.334963e-16        0.0     1.812987e-16
# -1.94           0.0        2.339518e-16        0.0     1.812987e-16
# -1.92           0.0        2.344249e-16        0.0     1.812987e-16
# -1.90           0.0        2.349163e-16        0.0     1.812987e-16
#
#        Normalized Error
# X
# -1.98               0.0
# -1.96               0.0
# -1.94               0.0
# -1.92               0.0
# -1.90               0.0

# %%
df[['Lib Error', 'VarDbl Error', 'VarDbl Uncertainty']]\
    .plot(title=r'Numerical errors for log($e^x$) - x', style=['k--', 'k.', 'k-'], grid=True)
# Out:
# <AxesSubplot:title={'center':'Numerical errors for log($e^x$) - x'}, xlabel='X'>

# %%
df.hist(column='Normalized Error')
# Out:
# array([[<AxesSubplot:title={'center':'Normalized Error'}>]], dtype=object)
